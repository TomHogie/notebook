# %%
import numpy as np
import pandas as pd
import matplotlib

# %%
file ='DATA\dictionary.csv'
countries_df=pd.read_csv(file)
countries_df.head()
# Out:
#            Country Code  Population  GDP per Capita
# 0      Afghanistan  AFG  32526562.0      594.323081
# 1          Albania  ALB   2889167.0     3945.217582
# 2          Algeria  ALG  39666519.0     4206.031232
# 3  American Samoa*  ASA     55538.0             NaN
# 4          Andorra  AND     70473.0             NaN

# %%
file ='DATA\summer.csv'
summer_df=pd.read_csv(file)
summer_df.head()
# Out:
#    Year    City     Sport Discipline             Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis     GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon     GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver

# %%
summer_df.rename(columns={"Country":"Code"},inplace = True)
summer_df.head()
# Out:
#    Year    City     Sport Discipline             Athlete Code Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver

# %%
summer_df.head()
# Out:
#    Year    City     Sport Discipline             Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis     GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon     GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver

# %%
file ='DATA\winter.csv'
winter_df=pd.read_csv(file)
winter_df.rename(columns={"Country":"Code"},inplace = True)
winter_df.head()
# Out:
#    Year      City     Sport Discipline               Athlete Code Gender  \
# 0  1924  Chamonix  Biathlon   Biathlon           BERTHET, G.  FRA    Men
# 1  1924  Chamonix  Biathlon   Biathlon        MANDRILLON, C.  FRA    Men
# 2  1924  Chamonix  Biathlon   Biathlon   MANDRILLON, Maurice  FRA    Men
# 3  1924  Chamonix  Biathlon   Biathlon       VANDELLE, André  FRA    Men
# 4  1924  Chamonix  Biathlon   Biathlon  AUFDENBLATTEN, Adolf  SUI    Men
#
#              Event   Medal
# 0  Military Patrol  Bronze
# 1  Military Patrol  Bronze
# 2  Military Patrol  Bronze
# 3  Military Patrol  Bronze
# 4  Military Patrol    Gold

# %%
summer_countries_df= countries_df.merge(summer_df,how='inner',on='Code')
summer_countries_df["Season"] = "Summer"

# %%
summer_countries_df.head()
# Out:
#        Country Code  Population  GDP per Capita  Year         City      Sport  \
# 0  Afghanistan  AFG  32526562.0      594.323081  2008      Beijing  Taekwondo
# 1  Afghanistan  AFG  32526562.0      594.323081  2012       London  Taekwondo
# 2      Algeria  ALG  39666519.0     4206.031232  1984  Los Angeles     Boxing
# 3      Algeria  ALG  39666519.0     4206.031232  1984  Los Angeles     Boxing
# 4      Algeria  ALG  39666519.0     4206.031232  1992    Barcelona  Athletics
#
#   Discipline             Athlete Gender                          Event  \
# 0  Taekwondo    NIKPAI, Rohullah    Men                        - 58 KG
# 1  Taekwondo    NIKPAI, Rohullah    Men                     58 - 68 KG
# 2     Boxing      ZAOUI, Mohamed    Men                        71-75KG
# 3     Boxing    MOUSSA, Mustapha    Men  75 - 81KG (Light-Heavyweight)
# 4  Athletics  BOULMERKA, Hassiba  Women                          1500M
#
#     Medal  Season
# 0  Bronze  Summer
# 1  Bronze  Summer
# 2  Bronze  Summer
# 3  Bronze  Summer
# 4    Gold  Summer

# %%
winter_countries_df= countries_df.merge(winter_df,how='inner',on='Code')
winter_countries_df["Season"] = "Winter"
winter_countries_df.head()
# Out:
#      Country Code  Population  GDP per Capita  Year         City    Sport  \
# 0  Australia  AUS  23781169.0    56310.962993  1994  Lillehammer  Skating
# 1  Australia  AUS  23781169.0    56310.962993  1994  Lillehammer  Skating
# 2  Australia  AUS  23781169.0    56310.962993  1994  Lillehammer  Skating
# 3  Australia  AUS  23781169.0    56310.962993  1994  Lillehammer  Skating
# 4  Australia  AUS  23781169.0    56310.962993  1998       Nagano   Skiing
#
#                   Discipline             Athlete Gender        Event   Medal  \
# 0  Short Track Speed Skating    BRADBURY, Steven    Men  5000M Relay  Bronze
# 1  Short Track Speed Skating      HANSEN, Kieran    Men  5000M Relay  Bronze
# 2  Short Track Speed Skating      MURTHA, Andrew    Men  5000M Relay  Bronze
# 3  Short Track Speed Skating  NIZIELSKI, Richard    Men  5000M Relay  Bronze
# 4              Alpine Skiing      STEGGALL, Zali  Women       Slalom  Bronze
#
#    Season
# 0  Winter
# 1  Winter
# 2  Winter
# 3  Winter
# 4  Winter

# %%
all_df = pd.concat([summer_countries_df, winter_countries_df], sort=False)
all_df.head()
# Out:
#        Country Code  Population  GDP per Capita  Year         City      Sport  \
# 0  Afghanistan  AFG  32526562.0      594.323081  2008      Beijing  Taekwondo
# 1  Afghanistan  AFG  32526562.0      594.323081  2012       London  Taekwondo
# 2      Algeria  ALG  39666519.0     4206.031232  1984  Los Angeles     Boxing
# 3      Algeria  ALG  39666519.0     4206.031232  1984  Los Angeles     Boxing
# 4      Algeria  ALG  39666519.0     4206.031232  1992    Barcelona  Athletics
#
#   Discipline             Athlete Gender                          Event  \
# 0  Taekwondo    NIKPAI, Rohullah    Men                        - 58 KG
# 1  Taekwondo    NIKPAI, Rohullah    Men                     58 - 68 KG
# 2     Boxing      ZAOUI, Mohamed    Men                        71-75KG
# 3     Boxing    MOUSSA, Mustapha    Men  75 - 81KG (Light-Heavyweight)
# 4  Athletics  BOULMERKA, Hassiba  Women                          1500M
#
#     Medal  Season
# 0  Bronze  Summer
# 1  Bronze  Summer
# 2  Bronze  Summer
# 3  Bronze  Summer
# 4    Gold  Summer

# %%
percountry_df = all_df[all_df["Year"]>1984].groupby("Country").count()["Medal"].sort_values(by= "Medal", ascending=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-575c905a0888> in <module>
#       1
# ----> 2 percountry_df = all_df[all_df["Year"]>1984].groupby("Country").count()["Medal"].sort_values(by="Medal", ascending=False)
#       3 percountry_df
#
# TypeError: sort_values() got an unexpected keyword argument 'by'

# %%
all_count_df = all_df[all_df["Year"] >= 1984] \
    .groupby(["Country"]) \
    .count()[["Medal"]] \
    .sort_values(by="Medal", ascending=False)
all_count_df.head(10)
# Out:
#                Medal
# Country
# United States   2472
# Germany         1112
# Russia          1031
# Australia        891
# China            889
# Canada           801
# Italy            632
# Korea, South     587
# France           587
# Netherlands      563

# %%
season_count_df = all_df.groupby(["Country", "Season"])["Medal"].count().unstack()
season_count_df.fillna(0, inplace=True)
season_count_df["Summer"] = season_count_df["Summer"].astype(int)
season_count_df["Summer"].head()
# Out:
# Country
# Afghanistan       2
# Algeria          15
# Argentina       259
# Armenia          11
# Australia      1189
# Name: Summer, dtype: int32

# %%
season_count_df["Winter"] = season_count_df["Winter"].astype(int)
season_count_df.head(10)
# Out:
# Season       Summer  Winter
# Country
# Afghanistan       2       0
# Algeria          15       0
# Argentina       259       0
# Armenia          11       0
# Australia      1189      15
# Austria         146     280
# Azerbaijan       26       0
# Bahamas          27       0
# Bahrain           1       0
# Barbados          1       0

# %%
season_count_df["Total"] = all_count_df
season_count_df.head(10)
# Out:
# Season       Summer  Winter  Total
# Country
# Afghanistan       2       0    2.0
# Algeria          15       0   15.0
# Argentina       259       0  173.0
# Armenia          11       0   11.0
# Australia      1189      15  891.0
# Austria         146     280  205.0
# Azerbaijan       26       0   26.0
# Bahamas          27       0   23.0
# Bahrain           1       0    1.0
# Barbados          1       0    1.0

# %%
season_count_df.sort_values(by="Total", ascending=False)[["Summer", "Winter"]].head(10).plot(kind="bar")
